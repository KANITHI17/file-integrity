# %%
# !pip install requests

# %%
import socket
import requests

# ------- Port Scanner -------
class PortScanner:
    def __init__(self, host, ports=range(1, 1025)):
        self.host = host
        self.ports = ports

    def scan(self):
        print(f"🔍 Scanning ports on {self.host}")
        for port in self.ports:
            try:
                with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
                    s.settimeout(0.3)
                    result = s.connect_ex((self.host, port))
                    if result == 0:
                        print(f"[+] Port {port} is OPEN")
            except Exception as e:
                print(f"Error scanning port {port}: {e}")

# ------- Brute-force Directory Scanner -------
class BruteForceScanner:
    def __init__(self, host, wordlist=None):
        self.host = host
        self.wordlist = wordlist or ["admin", "login", "dashboard", "test", "uploads"]

    def run(self):
        print(f"📂 Running brute-force scan on {self.host}")
        for path in self.wordlist:
            url = f"http://{self.host}/{path}"
            try:
                res = requests.get(url, timeout=2)
                if res.status_code == 200:
                    print(f"[+] Found: {url}")
            except requests.RequestException:
                pass

# ------- Unified Runner -------
def run_tool(host, port_scan=False, brute_scan=False):
    if port_scan:
        scanner = PortScanner(host)
        scanner.scan()
    if brute_scan:
        brute = BruteForceScanner(host)
        brute.run()

# %%
# ✅ Test the toolkit
run_tool(
    host="example.com",        # Replace with your test target
    port_scan=True,            # Enable port scanner
    brute_scan=True            # Enable directory brute-forcing
)
# Out:
# 🔍 Scanning ports on example.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3-974089452.py in <cell line: 0>()
#       1 # ✅ Test the toolkit
# ----> 2 run_tool(
#       3     host="example.com",        # Replace with your test target
#       4     port_scan=True,            # Enable port scanner
#       5     brute_scan=True            # Enable directory brute-forcing
#
# /tmp/ipython-input-2-3607566760.py in run_tool(host, port_scan, brute_scan)
#      41     if port_scan:
#      42         scanner = PortScanner(host)
# ---> 43         scanner.scan()
#      44     if brute_scan:
#      45         brute = BruteForceScanner(host)
#
# /tmp/ipython-input-2-3607566760.py in scan(self)
#      14                 with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
#      15                     s.settimeout(0.3)
# ...

# %%
custom_list = ["admin", "secret", "config"]
BruteForceScanner("example.com", wordlist=custom_list).run()
# Out:
# 📂 Running brute-force scan on example.com
